# %%
import pandas as pd

# %%
#url for draft and combine (2016-2020)

combine_2020 = 'https://www.pro-football-reference.com/draft/2020-combine.htm#combine'
combine_2019 = 'https://www.pro-football-reference.com/draft/2019-combine.htm'
combine_2018 = 'https://www.pro-football-reference.com/draft/2018-combine.htm'
combine_2017 = 'https://www.pro-football-reference.com/draft/2017-combine.htm'
combine_2016 =  'https://www.pro-football-reference.com/draft/2016-combine.htm'
draft_2020 = 'https://en.wikipedia.org/wiki/2020_NFL_Draft'
draft_2019 = 'https://en.wikipedia.org/wiki/2019_NFL_Draft'
draft_2018 = 'https://en.wikipedia.org/wiki/2018_NFL_Draft'
draft_2017 = 'https://en.wikipedia.org/wiki/2017_NFL_Draft'
draft_2016 = 'https://en.wikipedia.org/wiki/2016_NFL_Draft'

# %%
combine2020 = pd.read_html(combine_2020)
combine2019 = pd.read_html(combine_2019)
combine2018 = pd.read_html(combine_2018)
combine2017 = pd.read_html(combine_2017)
combine2016 = pd.read_html(combine_2016)
draft2020 = pd.read_html(draft_2020)
draft2019 = pd.read_html(draft_2019)
draft2018 = pd.read_html(draft_2018)
draft2017 = pd.read_html(draft_2017)
draft2016 = pd.read_html(draft_2016)

# %%
type(combine2020)
# Out:
# list

# %%
len(combine2020)
# Out:
# 1

# %%
combine_df_2020 = combine2020[0]
combine_df_2019 = combine2019[0]
combine_df_2018 = combine2018[0]
combine_df_2017 = combine2017[0]
combine_df_2016 = combine2016[0]
draft_df_2020 = draft2020[4]
draft_df_2019 = draft2019[4]
draft_df_2018 = draft2018[4]
draft_df_2017 = draft2017[4]
draft_df_2016 = draft2016[4]

# %%
combine_df_2020
# Out:
#                 Player Pos          School        College    Ht   Wt  40yd  \
# 0           Trey Adams  OL      Washington  College Stats   6-8  318  5.60
# 1       Hakeem Adeniji  OL          Kansas  College Stats   6-4  302  5.17
# 2        McTelvin Agim  DL        Arkansas  College Stats   6-3  309  4.98
# 3         Salvon Ahmed  RB      Washington  College Stats  5-11  197  4.62
# 4        Brandon Aiyuk  WR   Arizona State  College Stats   6-0  205  4.50
# ..                 ...  ..             ...            ...   ...  ...   ...
# 338        D.J. Wonnum  DL  South Carolina  College Stats   6-5  258  4.73
# 339  Dom Wood-Anderson  TE       Tennessee  College Stats   6-4  261  4.92
# 340     David Woodward  LB      Utah State  College Stats   6-2  230  4.79
# 341        Chase Young  DL      Ohio State  College Stats   6-5  264   NaN
# 342      Jabari Zuniga  DL         Florida  College Stats   6-3  264  4.64
#
#     Vertical Bench Broad Jump 3Cone Shuttle  \
# ...

# %%
combinedf2020 = combine_df_2020.drop(columns = ['Drafted (tm/rnd/yr)', 'College'], axis=1)
combinedf2019 = combine_df_2019.drop(columns = ['Drafted (tm/rnd/yr)', 'College'], axis=1)
combinedf2018 = combine_df_2018.drop(columns = ['Drafted (tm/rnd/yr)', 'College'], axis=1)
combinedf2017 = combine_df_2017.drop(columns = ['Drafted (tm/rnd/yr)', 'College'], axis=1)
combinedf2016 = combine_df_2016.drop(columns = ['Drafted (tm/rnd/yr)', 'College'], axis=1)
draftdf2020 = draft_df_2020.drop(columns = ['Unnamed: 0', 'Notes'], axis=1)
draft_df_2020
# Out:
#      Unnamed: 0 Rnd.  Pick #             NFL team            Player Pos.  \
# 0           NaN    1     1.0   Cincinnati Bengals        Joe Burrow   QB
# 1           NaN    1     2.0  Washington Redskins     Chase Youngʠ   DE
# 2           NaN    1     3.0        Detroit Lions       Jeff Okudah   CB
# 3           NaN    1     4.0      New York Giants     Andrew Thomas   OT
# 4           NaN    1     5.0       Miami Dolphins    Tua Tagovailoa   QB
# ..          ...  ...     ...                  ...               ...  ...
# 251         NaN   7*   251.0     Seattle Seahawks  Stephen Sullivan   TE
# 252         NaN   7*   252.0       Denver Broncos   Tyrie Cleveland   WR
# 253         NaN   7*   253.0    Minnesota Vikings       Kyle Hinton    C
# 254         NaN   7*   254.0       Denver Broncos     Derrek Tuszka   DE
# 255         NaN   7*   255.0      New York Giants       Tae Crowder   LB
#
#                 College    Conf.  \
# 0                   LSU      SEC
# ...

# %%
#Draft URL's
draft_2020 = 'https://en.wikipedia.org/wiki/2020_NFL_Draft'
draft_2019 = 'https://en.wikipedia.org/wiki/2019_NFL_Draft'
draft_2018 = 'https://en.wikipedia.org/wiki/2018_NFL_Draft'
draft_2017 = 'https://en.wikipedia.org/wiki/2017_NFL_Draft'
draft_2016 = 'https://en.wikipedia.org/wiki/2016_NFL_Draft'
