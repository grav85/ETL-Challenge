# %%
#Import Dependencies
import pandas as pd

# %% [markdown]
# ###2020 Draft Upload

# %%
#2020 Draft URL
url_2020 = 'https://en.wikipedia.org/wiki/2020_NFL_Draft'

# %%
#Read in 2020 NFL Draft Tables
table = pd.read_html(url_2020)
table_2020 = table[4]
table_2020
# Out:
#      Unnamed: 0 Rnd.  Pick #             NFL team            Player Pos.  \
# 0           NaN    1     1.0   Cincinnati Bengals        Joe Burrow   QB
# 1           NaN    1     2.0  Washington Redskins     Chase Youngʠ   DE
# 2           NaN    1     3.0        Detroit Lions       Jeff Okudah   CB
# 3           NaN    1     4.0      New York Giants     Andrew Thomas   OT
# 4           NaN    1     5.0       Miami Dolphins    Tua Tagovailoa   QB
# ..          ...  ...     ...                  ...               ...  ...
# 251         NaN   7*   251.0     Seattle Seahawks  Stephen Sullivan   TE
# 252         NaN   7*   252.0       Denver Broncos   Tyrie Cleveland   WR
# 253         NaN   7*   253.0    Minnesota Vikings       Kyle Hinton    C
# 254         NaN   7*   254.0       Denver Broncos     Derrek Tuszka   DE
# 255         NaN   7*   255.0      New York Giants       Tae Crowder   LB
#
#                 College    Conf.  \
# 0                   LSU      SEC
# ...

# %% [markdown]
# ###2019 Draft Upload

# %%
#2019 Draft URL
url_2019 = 'https://en.wikipedia.org/wiki/2019_NFL_Draft'

# %%
#Read in 2019 NFL Draft Tables
table = pd.read_html(url_2019)
table_2019 = table[4]
table_2019
# Out:
#      Unnamed: 0 Rnd.  Pick #              NFL team            Player Pos.  \
# 0           NaN    1     1.0     Arizona Cardinals    Kyler Murrayʠ   QB
# 1           NaN    1     2.0   San Francisco 49ers       Nick Bosaʠ   DE
# 2           NaN    1     3.0         New York Jets  Quinnen Williams   DT
# 3           NaN    1     4.0       Oakland Raiders    Clelin Ferrell   DE
# 4           NaN    1     5.0  Tampa Bay Buccaneers       Devin White  ILB
# ..          ...  ...     ...                   ...               ...  ...
# 251         NaN   7*   250.0     Minnesota Vikings    Austin Cutting   LS
# 252         NaN   7*   251.0      Los Angeles Rams      Dakota Allen   LB
# 253         NaN   7*   252.0  New England Patriots       Ken Webster   CB
# 254         NaN   7*   253.0   Washington Redskins  Jordan Brailford   DE
# 255         NaN   7*   254.0     Arizona Cardinals      Caleb Wilson   TE
#
#             College    Conf.  \
# 0          Oklahoma   Big 12
# ...

# %% [markdown]
# ###2018 Draft Upload

# %%
#2018 Draft URL
url_2018 = 'https://en.wikipedia.org/wiki/2018_NFL_Draft'

# %%
#Read in 2018 NFL Draft Tables
table = pd.read_html(url_2018)
table_2018 = table[4]
table_2018
# Out:
#      Unnamed: 0 Rnd.  Pick #             NFL team            Player Pos.  \
# 0           NaN    1       1     Cleveland Browns    Baker Mayfield   QB
# 1           NaN    1       2      New York Giants  Saquon Barkleyʠ   RB
# 2           NaN    1       3        New York Jets       Sam Darnold   QB
# 3           NaN    1       4     Cleveland Browns     Denzel Wardʠ   CB
# 4           NaN    1       5       Denver Broncos   Bradley Chubbʠ   LB
# ..          ...  ...     ...                  ...               ...  ...
# 251         NaN   7*     252   Cincinnati Bengals        Rod Taylor    G
# 252         NaN   7*     253   Cincinnati Bengals        Auden Tate   WR
# 253         NaN   7*     254    Arizona Cardinals  Korey Cunningham   OT
# 254         NaN   7*     255        Buffalo Bills     Austin Proehl   WR
# 255         NaN   7*     256  Washington Redskins        Trey Quinn   WR
#
#             College         Conf.                                  Notes
# ...

# %% [markdown]
# ###2017 Draft Upload

# %%
#2017 Draft URL
url_2017 = 'https://en.wikipedia.org/wiki/2017_NFL_Draft'

# %%
#Read in 2017 NFL Draft Tables
table = pd.read_html(url_2017)
table_2017 = table[4]
table_2017
# Out:
#      Unnamed: 0 Rnd.  Pick #              NFL team               Player Pos.  \
# 0           NaN    1     1.0      Cleveland Browns      Myles Garrettʠ   DE
# 1           NaN    1     2.0         Chicago Bears  Mitchell Trubiskyʠ   QB
# 2           NaN    1     3.0   San Francisco 49ers       Solomon Thomas   DE
# 3           NaN    1     4.0  Jacksonville Jaguars    Leonard Fournette   RB
# 4           NaN    1     5.0      Tennessee Titans          Corey Davis   WR
# ..          ...  ...     ...                   ...                  ...  ...
# 252         NaN    7   249.0      Seattle Seahawks         Chris Carson   RB
# 253         NaN    7   250.0         Detroit Lions         Pat O'Connor   DE
# 254         NaN   7*   251.0    Cincinnati Bengals        Mason Schreck   TE
# 255         NaN   7*   252.0      Cleveland Browns        Matthew Dayes   RB
# 256         NaN   7*   253.0        Denver Broncos           Chad Kelly   QB
#
# ...

# %% [markdown]
# ###2016 Draft Upload

# %%
#2016 Draft URL
url_2016 = 'https://en.wikipedia.org/wiki/2016_NFL_Draft'

# %%
#Read in 2016 NFL Draft Tables
table = pd.read_html(url_2016)
table_2016 = table[4]
table_2016
# Out:
#      Unnamed: 0 Rnd.  Pick #              NFL team                 Player  \
# 0           NaN    1     1.0      Los Angeles Rams           Jared Goffʠ
# 1           NaN    1     2.0   Philadelphia Eagles         Carson Wentzʠ
# 2           NaN    1     3.0    San Diego Chargers            Joey Bosaʠ
# 3           NaN    1     4.0        Dallas Cowboys      Ezekiel Elliottʠ
# 4           NaN    1     5.0  Jacksonville Jaguars         Jalen Ramseyʠ
# ..          ...  ...     ...                   ...                    ...
# 252         NaN    7   249.0   San Francisco 49ers  Prince Charles Iworah
# 253         NaN    7   250.0      Cleveland Browns          Scooby Wright
# 254         NaN    7   251.0   Philadelphia Eagles             Joe Walker
# 255         NaN    7   252.0     Carolina Panthers          Beau Sandland
# 256         NaN    7   253.0      Tennessee Titans             Kalan Reed
#
#     Pos.             College    Conf.                                 Notes
# ...
