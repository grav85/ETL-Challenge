# %% [markdown]
# # Setup

# %%
#Import Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
#Import Secrets
from secrets import username, password

# %% [markdown]
# # Combine - Get One Aggregate Dataframe

# %%
#Store URL's for NFL Combine by Season (2016-2020)
combine2016url =  'https://www.pro-football-reference.com/draft/2016-combine.htm'
combine2017url = 'https://www.pro-football-reference.com/draft/2017-combine.htm'
combine2018url = 'https://www.pro-football-reference.com/draft/2018-combine.htm'
combine2019url = 'https://www.pro-football-reference.com/draft/2019-combine.htm'
combine2020url = 'https://www.pro-football-reference.com/draft/2020-combine.htm#combine'

# %%
#Read in html tables from NFL Combine URL's
combine_2016 = pd.read_html(combine2016url)
combine_2017 = pd.read_html(combine2017url)
combine_2018 = pd.read_html(combine2018url)
combine_2019 = pd.read_html(combine2019url)
combine_2020 = pd.read_html(combine2020url)

# %%
#Check Data Type
type(combine_2016)
# Out:
# list

# %%
#Check how many tables are in the combine website
len(combine_2016)
# Out:
# 1

# %%
#Index the correct table and save in a variable
combine_df_2016 = combine_2016[0]
combine_df_2017 = combine_2017[0]
combine_df_2018 = combine_2018[0]
combine_df_2019 = combine_2019[0]
combine_df_2020 = combine_2020[0]

# %%
#Preview the Combine DF
combine_df_2016.head()
# Out:
#            Player Pos          School        College    Ht   Wt  40yd  \
# 0  Mehdi Abdesmad  DE     Boston Col.  College Stats   6-6  284  5.10
# 1    Vernon Adams  QB          Oregon  College Stats  5-11  200  4.83
# 2    Jerell Adams  TE  South Carolina  College Stats   6-5  247  4.64
# 3  Bralon Addison  WR          Oregon  College Stats   5-9  197  4.66
# 4  Roberto Aguayo   K   Florida State  College Stats   6-0  207  4.96
#
#   Vertical Bench Broad Jump 3Cone Shuttle  \
# 0     29.5    25        108  7.55    4.62
# 1     29.5   NaN        114  6.82    4.20
# 2     32.5   NaN        117  7.05    4.31
# 3     34.5    13        116  6.95    4.14
# 4      NaN   NaN        NaN   NaN     NaN
#
#                              Drafted (tm/rnd/yr)
# 0                                            NaN
# 1                                            NaN
# 2      New York Giants / 6th / 184th pick / 2016
# 3                                            NaN
# 4  Tampa Bay Buccaneers / 2nd / 59th pick / 2016

# %%
#Add Year to Combine DF's
combine_df_2016['Year']='2016'
combine_df_2017['Year']='2017'
combine_df_2018['Year']='2018'
combine_df_2019['Year']='2019'
combine_df_2020['Year']='2020'

# %%
#Preview the 2016 Combine DF with Added Year Column
combine_df_2016.head()
# Out:
#            Player Pos          School        College    Ht   Wt  40yd  \
# 0  Mehdi Abdesmad  DE     Boston Col.  College Stats   6-6  284  5.10
# 1    Vernon Adams  QB          Oregon  College Stats  5-11  200  4.83
# 2    Jerell Adams  TE  South Carolina  College Stats   6-5  247  4.64
# 3  Bralon Addison  WR          Oregon  College Stats   5-9  197  4.66
# 4  Roberto Aguayo   K   Florida State  College Stats   6-0  207  4.96
#
#   Vertical Bench Broad Jump 3Cone Shuttle  \
# 0     29.5    25        108  7.55    4.62
# 1     29.5   NaN        114  6.82    4.20
# 2     32.5   NaN        117  7.05    4.31
# 3     34.5    13        116  6.95    4.14
# 4      NaN   NaN        NaN   NaN     NaN
#
#                              Drafted (tm/rnd/yr)  Year
# 0                                            NaN  2016
# 1                                            NaN  2016
# 2      New York Giants / 6th / 184th pick / 2016  2016
# 3                                            NaN  2016
# 4  Tampa Bay Buccaneers / 2nd / 59th pick / 2016  2016

# %%
#Create One Big Combined DF for all Years - Combine
frames = [combine_df_2016, combine_df_2017, combine_df_2018, combine_df_2019, combine_df_2020]
combined_combine_df = pd.concat(frames)

# %%
#Preview Combined Combine DF
combined_combine_df.head()
# Out:
#            Player Pos          School        College    Ht   Wt  40yd  \
# 0  Mehdi Abdesmad  DE     Boston Col.  College Stats   6-6  284  5.10
# 1    Vernon Adams  QB          Oregon  College Stats  5-11  200  4.83
# 2    Jerell Adams  TE  South Carolina  College Stats   6-5  247  4.64
# 3  Bralon Addison  WR          Oregon  College Stats   5-9  197  4.66
# 4  Roberto Aguayo   K   Florida State  College Stats   6-0  207  4.96
#
#   Vertical Bench Broad Jump 3Cone Shuttle  \
# 0     29.5    25        108  7.55    4.62
# 1     29.5   NaN        114  6.82    4.20
# 2     32.5   NaN        117  7.05    4.31
# 3     34.5    13        116  6.95    4.14
# 4      NaN   NaN        NaN   NaN     NaN
#
#                              Drafted (tm/rnd/yr)  Year
# 0                                            NaN  2016
# 1                                            NaN  2016
# 2      New York Giants / 6th / 184th pick / 2016  2016
# 3                                            NaN  2016
# 4  Tampa Bay Buccaneers / 2nd / 59th pick / 2016  2016

# %%
#Clean up Combined Combine DF -- Rename and Drop Columns Where Necessary
combined_combine_df = combined_combine_df.rename(columns = {'40yd':'Forty_Yard', '3Cone': 'Three_Cone', 'Broad Jump': 'Broad_Jump'})
combined_combine_df = combined_combine_df.drop(['College', 'Drafted (tm/rnd/yr)'], axis=1)

# %%
#Preview Cleaned Up Combined Combine DF
combined_combine_df.head()
# Out:
#            Player Pos          School    Ht   Wt Forty_Yard Vertical Bench  \
# 0  Mehdi Abdesmad  DE     Boston Col.   6-6  284       5.10     29.5    25
# 1    Vernon Adams  QB          Oregon  5-11  200       4.83     29.5   NaN
# 2    Jerell Adams  TE  South Carolina   6-5  247       4.64     32.5   NaN
# 3  Bralon Addison  WR          Oregon   5-9  197       4.66     34.5    13
# 4  Roberto Aguayo   K   Florida State   6-0  207       4.96      NaN   NaN
#
#   Broad_Jump Three_Cone Shuttle  Year
# 0        108       7.55    4.62  2016
# 1        114       6.82    4.20  2016
# 2        117       7.05    4.31  2016
# 3        116       6.95    4.14  2016
# 4        NaN        NaN     NaN  2016

# %% [markdown]
# # Player - Get One Aggregate Dataframe

# %%
#Create Player DF from Combine DF
combined_player_df = combined_combine_df[['Player', 'Pos', 'School']]

# %%
#Preview Player DF
combined_player_df.head()
# Out:
#            Player Pos          School
# 0  Mehdi Abdesmad  DE     Boston Col.
# 1    Vernon Adams  QB          Oregon
# 2    Jerell Adams  TE  South Carolina
# 3  Bralon Addison  WR          Oregon
# 4  Roberto Aguayo   K   Florida State

# %% [markdown]
# # Draft - Get One Aggregate Dataframe

# %%
#Store URL's for NFL Draft by Season (2016-2020)
draft2016 = 'https://en.wikipedia.org/wiki/2016_NFL_Draft'
draft2017 = 'https://en.wikipedia.org/wiki/2017_NFL_Draft'
draft2018 = 'https://en.wikipedia.org/wiki/2018_NFL_Draft'
draft2019 = 'https://en.wikipedia.org/wiki/2019_NFL_Draft'
draft2020 = 'https://en.wikipedia.org/wiki/2020_NFL_Draft'

# %%
#Read in html tables from NFL Draft URL's
draft_2016 = pd.read_html(draft2016)
draft_2017 = pd.read_html(draft2017)
draft_2018 = pd.read_html(draft2018)
draft_2019 = pd.read_html(draft2019)
draft_2020 = pd.read_html(draft2020)

# %%
#Check Data Type
type(draft_2016)
# Out:
# list

# %%
#Check how many tables are in the draft website
len(draft_2016)
# Out:
# 13

# %%
#Index the correct table and save in a variable
draft_df_2016 = draft_2016[4]
draft_df_2017 = draft_2017[4]
draft_df_2018 = draft_2018[4]
draft_df_2019 = draft_2019[4]
draft_df_2020 = draft_2020[4]

# %%
#Preview the Draft DF
draft_df_2016.head()
# Out:
#    Unnamed: 0 Rnd.  Pick #              NFL team             Player Pos.  \
# 0         NaN    1     1.0      Los Angeles Rams       Jared Goff †   QB
# 1         NaN    1     2.0   Philadelphia Eagles     Carson Wentz †   QB
# 2         NaN    1     3.0    San Diego Chargers        Joey Bosa †   DE
# 3         NaN    1     4.0        Dallas Cowboys  Ezekiel Elliott †   RB
# 4         NaN    1     5.0  Jacksonville Jaguars     Jalen Ramsey †   CB
#
#               College    Conf.                    Notes
# 0          California   Pac-12  from Tennessee [R1 - 1]
# 1  North Dakota State     MVFC  from Cleveland [R1 - 2]
# 2          Ohio State  Big Ten                      NaN
# 3          Ohio State  Big Ten                      NaN
# 4       Florida State      ACC                      NaN

# %%
#Add Year to Draft DF's
draft_df_2016['Year']='2016'
draft_df_2017['Year']='2017'
draft_df_2018['Year']='2018'
draft_df_2019['Year']='2019'
draft_df_2020['Year']='2020'

# %%
#Preview the 2016 Draft DF with Added Year Column
draft_df_2016.head()
# Out:
#    Unnamed: 0 Rnd.  Pick #              NFL team             Player Pos.  \
# 0         NaN    1     1.0      Los Angeles Rams       Jared Goff †   QB
# 1         NaN    1     2.0   Philadelphia Eagles     Carson Wentz †   QB
# 2         NaN    1     3.0    San Diego Chargers        Joey Bosa †   DE
# 3         NaN    1     4.0        Dallas Cowboys  Ezekiel Elliott †   RB
# 4         NaN    1     5.0  Jacksonville Jaguars     Jalen Ramsey †   CB
#
#               College    Conf.                    Notes  Year
# 0          California   Pac-12  from Tennessee [R1 - 1]  2016
# 1  North Dakota State     MVFC  from Cleveland [R1 - 2]  2016
# 2          Ohio State  Big Ten                      NaN  2016
# 3          Ohio State  Big Ten                      NaN  2016
# 4       Florida State      ACC                      NaN  2016

# %%
#Create One Big Combined DF for all Years - Draft
frames = [draft_df_2016, draft_df_2017, draft_df_2018, draft_df_2019, draft_df_2020]
combined_draft_df = pd.concat(frames)

# %%
#Preview Combined Draft DF
combined_draft_df.head()
# Out:
#    Unnamed: 0 Rnd.  Pick #              NFL team             Player Pos.  \
# 0         NaN    1     1.0      Los Angeles Rams       Jared Goff †   QB
# 1         NaN    1     2.0   Philadelphia Eagles     Carson Wentz †   QB
# 2         NaN    1     3.0    San Diego Chargers        Joey Bosa †   DE
# 3         NaN    1     4.0        Dallas Cowboys  Ezekiel Elliott †   RB
# 4         NaN    1     5.0  Jacksonville Jaguars     Jalen Ramsey †   CB
#
#               College    Conf.                    Notes  Year
# 0          California   Pac-12  from Tennessee [R1 - 1]  2016
# 1  North Dakota State     MVFC  from Cleveland [R1 - 2]  2016
# 2          Ohio State  Big Ten                      NaN  2016
# 3          Ohio State  Big Ten                      NaN  2016
# 4       Florida State      ACC                      NaN  2016

# %%
#Clean up Combined Combine DF -- Rename and Drop Columns Where Necessary
combined_draft_df = combined_draft_df.rename(columns = {'Rnd.': 'Round', 'Pick #': 'Pick_No', 'Pos.': 'Pos', 'Conf.': 'Conf'})
combined_draft_df = combined_draft_df.drop(['Unnamed: 0', 'Notes', 'NFL team'], axis=1)

# %%
#Preview Cleaned Up Combined Draft DF
combined_draft_df.head()
# Out:
#   Round  Pick_No             Player Pos             College     Conf  Year
# 0     1      1.0       Jared Goff †  QB          California   Pac-12  2016
# 1     1      2.0     Carson Wentz †  QB  North Dakota State     MVFC  2016
# 2     1      3.0        Joey Bosa †  DE          Ohio State  Big Ten  2016
# 3     1      4.0  Ezekiel Elliott †  RB          Ohio State  Big Ten  2016
# 4     1      5.0     Jalen Ramsey †  CB       Florida State      ACC  2016

# %% [markdown]
# # Load

# %%
#Connect to Local SQL Database
rds_connection_string = f'{username}:{password}@localhost:5432/NFL_DB'
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### First, create Player table in PostgreSQL, then execute code below:

# %%
# Check the tables names to make sure where are we posting
engine.table_names()
# Out:
# ['player']

# %%
# Append data using pandas. name stands for table name, change it if neccesary.
combined_player_df.to_sql(name='player', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\envs\DBenv\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\anaconda3\envs\DBenv\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UndefinedColumn: column "Player" of relation "player" does not exist
# LINE 1: INSERT INTO player ("Player", "Pos", "School") VALUES ('Mehd...
#                             ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-33-7b5212ec1d17> in <module>
#       1 # Append data using pandas. name stands for table name, change it if neccesary.
# ----> 2 combined_player_df.to_sql(name='player', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\DBenv\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2784             chunksize=chunksize,
#    2785             dtype=dtype,
# -> 2786             method=method,
#    2787         )
#    2788
#
# ~\anaconda3\envs\DBenv\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     597         chunksize=chunksize,
#     598         dtype=dtype,
# --> 599         method=method,
#     600     )
#     601
#
# ~\anaconda3\envs\DBenv\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1403                 raise ValueError("inf cannot be used with MySQL") from err
#    1404             else:
# -> 1405                 raise err
#    1406
#    1407         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\envs\DBenv\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1395
#    1396         try:
# -> 1397             table.insert(chunksize, method=method)
#    1398         except exc.SQLAlchemyError as err:
#    1399             # GH34431
#
# ~\anaconda3\envs\DBenv\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     829
#     830                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 831                 exec_insert(conn, keys, chunk_iter)
#     832
#     833     def _query_iterator(
#
# ~\anaconda3\envs\DBenv\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     746         """
#     747         data = [dict(zip(keys, row)) for row in data_iter]
# --> 748         conn.execute(self.table.insert(), data)
#     749
#     750     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\DBenv\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\DBenv\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\DBenv\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1128             distilled_params,
#    1129             compiled_sql,
# -> 1130             distilled_params,
#    1131         )
#    1132         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\DBenv\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# ~\anaconda3\envs\DBenv\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509             elif should_wrap:
#    1510                 util.raise_(
# -> 1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#    1513             else:
#
# ~\anaconda3\envs\DBenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\DBenv\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#    1259             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\DBenv\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "Player" of relation "player" does not exist
# LINE 1: INSERT INTO player ("Player", "Pos", "School") VALUES ('Mehd...
#                             ^
#
# [SQL: INSERT INTO player ("Player", "Pos", "School") VALUES (%(Player)s, %(Pos)s, %(School)s)]
# [parameters: ({'Player': 'Mehdi Abdesmad', 'Pos': 'DE', 'School': 'Boston Col.'}, {'Player': 'Vernon Adams', 'Pos': 'QB', 'School': 'Oregon'}, {'Player': 'Jerell Adams', 'Pos': 'TE', 'School': 'South Carolina'}, {'Player': 'Bralon Addison', 'Pos': 'WR', 'School': 'Oregon'}, {'Player': 'Roberto Aguayo', 'Pos': 'K', 'School': 'Florida State'}, {'Player': 'Mackensie Alexander', 'Pos': 'CB', 'School': 'Clemson'}, {'Player': 'Dominique Alexander', 'Pos': 'ILB', 'School': 'Oklahoma'}, {'Player': 'Vadal Alexander', 'Pos': 'OT', 'School': 'LSU'}  ... displaying 10 of 1699 total bound parameter sets ...  {'Player': 'Chase Young', 'Pos': 'DL', 'School': 'Ohio State'}, {'Player': 'Jabari Zuniga', 'Pos': 'DL', 'School': 'Florida'})]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
#Confirm the data has been appended. Check table name.
pd.read_sql_query('select * from player', con=engine).head()

# %%
player_id_df=pd.read_sql_query('select * from player', con=engine)
player_id_df

# %%
combine_df_final = pd.merge(combine_df, player_id_df, how='inner', on='player')
combine_df_final

# %%
combine_df_final = combine_df_final.drop(columns = ['school', 'School','player'])
combine_df_final = combine_df_final.rename(columns = {'id':'player_id'})
combine_df_final

# %%
combine_table=engine.execute('SELECT * FROM combine')
print(combine_table.keys())

# %%
#OLD CODE FOR REFERENCE
combine_df = combine_df_2020.append(combine_df_2019,ignore_index=True,verify_integrity=True)
combine_df = combine_df.append(combine_df_2018,ignore_index=True,verify_integrity=True)
combine_df = combine_df.append(combine_df_2017,ignore_index=True,verify_integrity=True)
combine_df = combine_df.append(combine_df_2016,ignore_index=True,verify_integrity=True)
combine_df = combine_df.rename(columns = {'Player': 'player'})
combine_df = combine_df.drop(columns = {'Pos'})
combine_df
